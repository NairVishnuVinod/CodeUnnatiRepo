# %%
import pandas as pd

df = pd.read_csv("nba-2.csv")

df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25   2-Jun     180
# 1      Jae Crowder  Boston Celtics      99       SF   25   6-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27   5-Jun     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22   5-Jun     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  10-Jun     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF   20  10-Jun     234
# 453   Shelvin Mack       Utah Jazz       8       PG   26   3-Jun     203
# 454      Raul Neto       Utah Jazz      25       PG   24   1-Jun     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26   3-Jul     256
# 456    Jeff Withey       Utah Jazz      24        C   26  Jul-00     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
first = df.groupby('Team')
first.last()  # .first() && .last()
# Out:
#                                      Name  Number Position  Age  Height  \
# Team
# Atlanta Hawks                 Jeff Teague       0       PG   27   2-Jun
# Boston Celtics               Tyler Zeller      44        C   26  Jul-00
# Brooklyn Nets              Thaddeus Young      30       PF   27   8-Jun
# Charlotte Hornets             Cody Zeller      40        C   23  Jul-00
# Chicago Bulls                  Tony Snell      20       SF   24   7-Jun
# Cleveland Cavaliers           Mo Williams      52       PG   33   1-Jun
# Dallas Mavericks           Deron Williams       8       PG   31   3-Jun
# Denver Nuggets               Axel Toupane       6       SG   23   7-Jun
# Detroit Pistons          Anthony Tolliver      43       PF   31   8-Jun
# Golden State Warriors    Anderson Varejao      18       PF   33  11-Jun
# Houston Rockets               Jason Terry      31       SG   38   2-Jun
# Indiana Pacers                  Joe Young       1       PG   23   2-Jun
# ...

# %%
first.get_group('Golden State Warriors')
# Out:
#                     Name                   Team  Number Position  Age  Height  \
# 76       Leandro Barbosa  Golden State Warriors      19       SG   33   3-Jun
# 77       Harrison Barnes  Golden State Warriors      40       SF   24   8-Jun
# 78          Andrew Bogut  Golden State Warriors      12        C   31  Jul-00
# 79             Ian Clark  Golden State Warriors      21       SG   25   3-Jun
# 80         Stephen Curry  Golden State Warriors      30       PG   28   3-Jun
# 81          Festus Ezeli  Golden State Warriors      31        C   26  11-Jun
# 82        Draymond Green  Golden State Warriors      23       PF   26   7-Jun
# 83        Andre Iguodala  Golden State Warriors       9       SF   32   6-Jun
# 84      Shaun Livingston  Golden State Warriors      34       PG   30   7-Jun
# 85          Kevon Looney  Golden State Warriors      36       SF   20   9-Jun
# 86  James Michael McAdoo  Golden State Warriors      20       SF   23   9-Jun
# ...

# %%
second = df.groupby(['Age','Position','Team'])
second.last()
# Out:
#                                                    Name  Number  Height  \
# Age Position Team
# 19  SG       Milwaukee Bucks              Rashad Vaughn      20   6-Jun
#              Phoenix Suns                  Devin Booker       1   6-Jun
# 20  C        Minnesota Timberwolves  Karl-Anthony Towns      32  Jul-00
#              Philadelphia 76ers           Jahlil Okafor       8  11-Jun
#     PF       Indiana Pacers                Myles Turner      33  11-Jun
# ...                                                 ...     ...     ...
# 39  PG       Los Angeles Clippers        Pablo Prigioni       9   3-Jun
#     SG       Memphis Grizzlies             Vince Carter      15   6-Jun
# 40  C        San Antonio Spurs               Tim Duncan      21  11-Jun
#     PF       Minnesota Timberwolves       Kevin Garnett      21  11-Jun
#     PG       San Antonio Spurs             Andre Miller      24   3-Jun
#
#                                      Weight         College     Salary
# ...
